# %% [markdown]
# <p align="left">
#   <img src="../data/imagen/escudo_uach.png" width="100">
# </p>
#
# # Procesamiento Digital de Señales ACUS099
#
# ## Integrantes: Patricio Elgueda & Antonella Roco
#
# ### Tabla de contenidos:
# 1) Transformada de Fourier
# 2) NO SE que más
# 3) NO SE
# 4) Conclusiones
# 5) Referencias
